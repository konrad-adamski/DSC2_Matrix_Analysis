# %% [markdown]
# # MDS Zusammenführung

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dsc_path = "../data/010_dsc.csv"

# %% [markdown]
# ## 1) Mit Mean

# %%
# Einlesen der CSV-Datei
df_experiments_mds = pd.read_csv("data/mds_intervals_mean.csv", index_col=0)
df_experiments_mds
# Out:
#            -24       -23       -22       -21       -20       -19       -18  \
# L001 -1.895041 -1.882417 -1.867989 -1.850984 -1.830373 -1.806670 -1.783225
# L002 -1.897818 -1.881884 -1.865950 -1.848126 -1.825441 -1.803565 -1.784931
# L003 -1.855503 -1.836973 -1.818703 -1.803566 -1.787906 -1.768071 -1.744321
# L004 -1.765930 -1.754211 -1.737699 -1.719323 -1.702012 -1.687897 -1.674847
# L005 -1.863076 -1.848531 -1.827214 -1.807151 -1.790098 -1.770788 -1.751227
# ...        ...       ...       ...       ...       ...       ...       ...
# L383 -1.750991 -1.737117 -1.727466 -1.711984 -1.700925 -1.687856 -1.672574
# L384 -1.644064 -1.634867 -1.624793 -1.612968 -1.600997 -1.590339 -1.579974
# L385 -1.744776 -1.734210 -1.724028 -1.711348 -1.698476 -1.686181 -1.671004
# L386 -1.698102 -1.685843 -1.672547 -1.660633 -1.649582 -1.638531 -1.621091
# L387 -1.683924 -1.668554 -1.656353 -1.647321 -1.636070 -1.624820 -1.612777
#
# ...

# %%
# Visualisierung der MDS-Ergebnisse
plt.figure(figsize=(10, 8))
plt.scatter(df_experiments_mds["MDS1_mean"], df_experiments_mds["MDS2_mean"], c='blue', alpha=0.6)
plt.title("Relative Position der Proben (MDS)")
plt.xlabel("MDS1_mean")
plt.ylabel("MDS2_mean")

# Beschriftung der Punkte mit den Probenbezeichnungen
for i, txt in enumerate(df_experiments_mds.index):
    plt.annotate(txt, (df_experiments_mds["MDS1_mean"].iloc[i], df_experiments_mds["MDS2_mean"].iloc[i]))

plt.show()

# %%
df_dsc = pd.read_csv(dsc_path, index_col=0)
df_dsc
# Out:
#            Probenbezeichnung  Konzentration_ppm      Matrix      Polymer  \
# Nummer
# L001        Mod.S-PE_1_25ppm                 25  Modellsand  Polyethylen
# L002        Mod.S-PE_1_25ppm                 25  Modellsand  Polyethylen
# L003        Mod.S-PE_1_25ppm                 25  Modellsand  Polyethylen
# L004        Mod.S-PE_1_50ppm                 50  Modellsand  Polyethylen
# L005        Mod.S-PE_1_50ppm                 50  Modellsand  Polyethylen
# ...                      ...                ...         ...          ...
# L371    DS Sand-PE-20ppm-1_2                 20        Sand  Polyethylen
# L372    DS Sand-PE-20ppm-1_2                 20        Sand  Polyethylen
# L373    DS Sand-PE-20ppm-2_2                 20        Sand  Polyethylen
# L374    DS Sand-PE-20ppm-2_2                 20        Sand  Polyethylen
# L375    DS Sand-PE-20ppm-2_2                 20        Sand  Polyethylen
#
#         Masse Polymer  Alterung  mProben_mg  dHm_J/g   Tm_C
# Nummer
# ...

# %%
merged_df = df_dsc.join(df_experiments_mds, how="left")
merged_df
# Out:
#            Probenbezeichnung  Konzentration_ppm      Matrix      Polymer  \
# Nummer
# L001        Mod.S-PE_1_25ppm                 25  Modellsand  Polyethylen
# L002        Mod.S-PE_1_25ppm                 25  Modellsand  Polyethylen
# L003        Mod.S-PE_1_25ppm                 25  Modellsand  Polyethylen
# L004        Mod.S-PE_1_50ppm                 50  Modellsand  Polyethylen
# L005        Mod.S-PE_1_50ppm                 50  Modellsand  Polyethylen
# ...                      ...                ...         ...          ...
# L371    DS Sand-PE-20ppm-1_2                 20        Sand  Polyethylen
# L372    DS Sand-PE-20ppm-1_2                 20        Sand  Polyethylen
# L373    DS Sand-PE-20ppm-2_2                 20        Sand  Polyethylen
# L374    DS Sand-PE-20ppm-2_2                 20        Sand  Polyethylen
# L375    DS Sand-PE-20ppm-2_2                 20        Sand  Polyethylen
#
#         Masse Polymer  Alterung  mProben_mg  dHm_J/g   Tm_C       -24  ...  \
# ...

# %%
# Manuelle Zuordnung der Farben zu den "Matrix"-Kategorien
category_color_map = {
    "Modellsand": "#FFD580",  # Helles Orange
    "Sand": "#FF7F00",        # Dunkleres Orange
    "Sediment Weißeritz": "green",
    "Sediment Elbe": "red"
}

# %%
# Unique categories in the "Matrix" column
unique_categories = merged_df["Matrix"].unique()

# Map the colors to the "Matrix" column
merged_df["Color_Code"] = merged_df["Matrix"].map(category_color_map)

# Plotting
plt.figure(figsize=(10, 8))
for category, color in category_color_map.items():
    subset = merged_df[merged_df["Matrix"] == category]
    plt.scatter(subset["MDS1_mean"], subset["MDS2_mean"], label=category, color=color, alpha=0.6)

# Add legend
plt.legend(title="Matrix Kategorien", loc='best')
plt.title("Relative Position der Proben (MDS)")
plt.xlabel("MDS1_mean")
plt.ylabel("MDS2_mean")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 2) Pro Intervall

# %%
# Einlesen der CSV-Datei
df_experiments_mds = pd.read_csv("data/mds_intervals.csv", index_col=0)
df_experiments_mds
# Out:
#            -24       -23       -22       -21       -20       -19       -18  \
# L001 -1.895041 -1.882417 -1.867989 -1.850984 -1.830373 -1.806670 -1.783225
# L002 -1.897818 -1.881884 -1.865950 -1.848126 -1.825441 -1.803565 -1.784931
# L003 -1.855503 -1.836973 -1.818703 -1.803566 -1.787906 -1.768071 -1.744321
# L004 -1.765930 -1.754211 -1.737699 -1.719323 -1.702012 -1.687897 -1.674847
# L005 -1.863076 -1.848531 -1.827214 -1.807151 -1.790098 -1.770788 -1.751227
# ...        ...       ...       ...       ...       ...       ...       ...
# L383 -1.750991 -1.737117 -1.727466 -1.711984 -1.700925 -1.687856 -1.672574
# L384 -1.644064 -1.634867 -1.624793 -1.612968 -1.600997 -1.590339 -1.579974
# L385 -1.744776 -1.734210 -1.724028 -1.711348 -1.698476 -1.686181 -1.671004
# L386 -1.698102 -1.685843 -1.672547 -1.660633 -1.649582 -1.638531 -1.621091
# L387 -1.683924 -1.668554 -1.656353 -1.647321 -1.636070 -1.624820 -1.612777
#
# ...

# %%
merged_df = df_dsc.join(df_experiments_mds, how="left")
merged_df
# Out:
#            Probenbezeichnung  Konzentration_ppm      Matrix      Polymer  \
# Nummer
# L001        Mod.S-PE_1_25ppm                 25  Modellsand  Polyethylen
# L002        Mod.S-PE_1_25ppm                 25  Modellsand  Polyethylen
# L003        Mod.S-PE_1_25ppm                 25  Modellsand  Polyethylen
# L004        Mod.S-PE_1_50ppm                 50  Modellsand  Polyethylen
# L005        Mod.S-PE_1_50ppm                 50  Modellsand  Polyethylen
# ...                      ...                ...         ...          ...
# L371    DS Sand-PE-20ppm-1_2                 20        Sand  Polyethylen
# L372    DS Sand-PE-20ppm-1_2                 20        Sand  Polyethylen
# L373    DS Sand-PE-20ppm-2_2                 20        Sand  Polyethylen
# L374    DS Sand-PE-20ppm-2_2                 20        Sand  Polyethylen
# L375    DS Sand-PE-20ppm-2_2                 20        Sand  Polyethylen
#
#         Masse Polymer  Alterung  mProben_mg  dHm_J/g   Tm_C       -24  ...  \
# ...

# %%
import matplotlib.pyplot as plt

# Identifizieren der Intervalle aus den MDS-Spalten
mds_intervals = [
    col.split("_")[-1] for col in merged_df.columns if col.startswith("MDS1_")
]

# Unique categories in the "Matrix" column
unique_categories = merged_df["Matrix"].unique()

# Iterative Plots für jedes Intervall
for interval in mds_intervals:
    mds1_col = f"MDS1_{interval}"
    mds2_col = f"MDS2_{interval}"

    # Plot für das aktuelle Intervall erstellen
    plt.figure(figsize=(10, 8))
    
    # Punkte nach Kategorie plotten
    for category, color in category_color_map.items():
        subset = merged_df[merged_df["Matrix"] == category]
        plt.scatter(
            subset[mds1_col], 
            subset[mds2_col], 
            label=category, 
            color=color, 
            alpha=0.6
        )
    
    # Titel und Achsenbeschriftung
    plt.title(f"Relative Position der Proben (MDS):  {interval}")
    plt.xlabel("MDS1")
    plt.ylabel("MDS2")
    plt.legend(title="Matrix Kategorien", loc='best')
    plt.grid(True)
    plt.show()
